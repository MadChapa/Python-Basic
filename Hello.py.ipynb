# %%
print("Hello world ")

# variables
 
city="kathmandu"
print(city)

city="Pokhara"
print(city)
# Out:
# Hello world
# kathmandu
# Pokhara

# %%
city="ktm"
destination_city="pokhara"
city=destination_city
print(city)
# Out:
# pokhara
